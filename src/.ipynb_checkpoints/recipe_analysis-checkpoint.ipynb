# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# Ricette definite in un formato semistrutturato, raggruppamento degli step e ingredienti in un unica stringa, funzioni di utilità

# %% [markdown]
# ### Funzioni util e import

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display
from ast import literal_eval
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree
from nltk.sem import relextract
import spacy
from spacy import displacy
from nltk.corpus import conll2000

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('conll2000')


# !python -m spacy download en_core_web_md

NLP = spacy.load('en_core_web_md')


def string_recipe(i):
    return dataset.iloc[i]['title'] + "\n\n" + dataset.iloc[i]['ingredients'] + "\n\n" + dataset.iloc[i]['step']
# Out:
# [nltk_data] Downloading package stopwords to /home/navis/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/navis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/navis/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/navis/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/navis/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package conll2000 to /home/navis/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# Collecting en-core-web-md==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.2.0/en_core_web_md-3.2.0-py3-none-any.whl (45.7 MB)
#      |████████████████████████████████| 45.7 MB 26.7 MB/s eta 0:00:01     |██████████████████████          | 31.4 MB 11.1 MB/s eta 0:00:02     |██████████████████████████      | 37.1 MB 26.7 MB/s eta 0:00:01     |███████████████████████████▍    | 39.1 MB 26.7 MB/s eta 0:00:01     |████████████████████████████    | 40.0 MB 26.7 MB/s eta 0:00:01     |█████████████████████████████▍  | 42.0 MB 26.7 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from en-core-web-md==3.2.0) (3.2.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.0.5)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (4.62.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.5)
# Requirement already satisfied: packaging>=20.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.27.1)
# Requirement already satisfied: pathy>=0.3.5 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.4.1)
# Requirement already satisfied: setuptools in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (58.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.21.2)
# Requirement already satisfied: jinja2 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (8.0.13)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/navis/anaconda3/envs/Progetto_GDNS/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# ### Caricamento del dataset

# %%
dataset = pd.read_csv(
    Path("../data/test_dataset.csv").resolve(), 
    index_col=[0], 
    names=["index", "title","ingredients","step"], 
    usecols=[0,1,2,3]
    )

for index in range(len(dataset)):
    dataset.iloc[index]['ingredients'] = ".\n".join(literal_eval(dataset.iloc[index]['ingredients']))
    dataset.iloc[index]['step'] = " ".join(literal_eval(dataset.iloc[index]['step']))

display(dataset.head())
print(string_recipe(10))
# Out:
#                           title  \
# index
# 1         Jewell Ball'S Chicken
# 2                   Creamy Corn
# 3                 Chicken Funny
# 4          Reeses Cups(Candy)
# 5      Cheeseburger Potato Soup
#
#                                              ingredients  \
# index
# 1      1 small jar chipped beef, cut up.\n4 boned chi...
# 2      2 (16 oz.) pkg. frozen corn.\n1 (8 oz.) pkg. c...
# 3      1 large whole chicken.\n2 (10 1/2 oz.) cans ch...
# 4      1 c. peanut butter.\n3/4 c. graham cracker cru...
# 5      6 baking potatoes.\n1 lb. of extra lean ground...
#
#                                                     step
# index
# 1      Place chipped beef on bottom of baking dish. P...
# 2      In a slow cooker, combine all ingredients. Cov...
# 3      Boil and debone chicken. Put bite size pieces ...
# 4      Combine first four ingredients and press in 13...
# 5      Wash potatoes; prick several times with a fork...
# Buckeye Candy
#
# 1 box powdered sugar.
# 8 oz. soft butter.
# 1 (8 oz.) peanut butter.
# paraffin.
# 12 oz. chocolate chips
#
# Mix sugar, butter and peanut butter. Roll into balls and place on cookie sheet. Set in freezer for at least 30 minutes. Melt chocolate chips and paraffin in double boiler. Using a toothpick, dip balls 3/4 of way into chocolate chip and paraffin mixture to make them look like buckeyes.

# %% [markdown]
# ### Estrazione delle abbreviazioni

# %% [markdown]
# Fase iniziale di ritrovamento del set di abbreviazioni

# %%
abbrv_dataset = pd.read_csv(
    Path("../data/test_dataset.csv").resolve(), 
    index_col=[0], 
    names=["index", "title","ingredients","step"], 
    usecols=[0,1,2,3]
    )

abbrv = set()
for index in range(len(dataset)):
    abbrv_dataset.iloc[index]['ingredients'] = " ".join(literal_eval(abbrv_dataset.iloc[index]['ingredients']))
    for element in re.findall(r"[A-Za-z]*\.", abbrv_dataset.iloc[index]['ingredients']):
        abbrv.add(element)
    
print(abbrv)
# Out:
# {'No.', 'pkg.', 'tsp.', 'c.', 'sq.', 'gal.', 'qt.', 'Tbsp.', 'tbsp.', 'lb.', 'oz.', 'pt.'}

# %% [markdown]
# Rimozione delle abbreviazioni in quanto possono essere dannose per il processo di tokenizzazione. Es pkg. ---> package

# %%
def expand_abbreviations(ingredients_string):
    __ABBREVIATIONS__ = {
        'pkg.'  :   'package',
        'tsb.'  :   'tablespoon',
        'no.'   :   'number',
        'pt.'   :   'pint',
        'no.'   :   'number',
        'gal.'  :   'gallon',
        'tbsp.' :   'tablespoon',
        'sq.'   :   'square',
        'oz.'   :   'ounce',
        'lb.'   :   'pound',
        'qt.'   :   'quart',
        'c.'    :   'cup',
        'tsp.'  :   'teaspoon'
    }
    for item, value in __ABBREVIATIONS__.items():
        ingredients_string = ingredients_string.lower().replace(item, value)
    return ingredients_string


for index in range(len(dataset)):
    dataset.iloc[index]['ingredients'] = expand_abbreviations(dataset.iloc[index]['ingredients'])

# %% [markdown]
# ### Sentence splitting
# Il contenuto delle colonne 'ingredients' e 'step' verrà suddiviso in frasi. In precedenza i periodi contenuti nelle singole celle sono stati formattati in modo tale da renderli riconoscibili e facilmente suddivisibili in frasi ben separate.

# %%
for index in range(len(dataset)):
     dataset.iloc[index]['ingredients'] = (sent_tokenize(dataset.iloc[index]['ingredients']))
print(dataset.iloc[10]['ingredients'])
# Out:
# ['1 box powdered sugar.', '8 ounce soft butter.', '1 (8 ounce) peanut butter.', 'paraffin.', '12 ounce chocolate chips']

# %%
for index in range(len(dataset)):
     dataset.iloc[index]['step'] = (sent_tokenize(dataset.iloc[index]['step']))
print(dataset.iloc[10]['step'])
# Out:
# ['Mix sugar, butter and peanut butter.', 'Roll into balls and place on cookie sheet.', 'Set in freezer for at least 30 minutes.', 'Melt chocolate chips and paraffin in double boiler.', 'Using a toothpick, dip balls 3/4 of way into chocolate chip and paraffin mixture to make them look like buckeyes.']

# %% [markdown]
# ### Rimozione quantità doppie

# %%
dr_reg = r'\d*\s*\(.*\)'

for index in range(len(dataset)):
    for value in range(len(dataset.iloc[index]['ingredients'])):
        elements = re.findall(dr_reg, dataset.iloc[index]['ingredients'][value])
        for e in elements:
            new_string = dataset.iloc[index]['ingredients'][value].replace(e,e[e.find("(")+1: e.find(")")].strip())
            dataset.iloc[index]['ingredients'][value] = new_string
# Out:
# 1 small jar chipped beef, cut up.
# []
# 4 boned chicken breasts.
# []
# 1 can cream of mushroom soup.
# []
# 1 carton sour cream
# []
# 2 (16 ounce) package frozen corn.
# ['2 (16 ounce)']
# 2 (16 ounce)
# 16 ounce package frozen corn.
# 1 (8 ounce) package cream cheese, cubed.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce package cream cheese, cubed.
# 1/3 cup butter, cubed.
# []
# 1/2 teaspoon garlic powder.
# []
# 1/2 teaspoon salt.
# []
# 1/4 teaspoon pepper
# []
# 1 large whole chicken.
# []
# 2 (10 1/2 ounce) cans chicken gravy.
# ['2 (10 1/2 ounce)']
# 2 (10 1/2 ounce)
# 10 1/2 ounce cans chicken gravy.
# 1 (10 1/2 ounce) can cream of mushroom soup.
# ['1 (10 1/2 ounce)']
# 1 (10 1/2 ounce)
# 10 1/2 ounce can cream of mushroom soup.
# 1 (6 ounce) box stove top stuffing.
# ['1 (6 ounce)']
# 1 (6 ounce)
# 6 ounce box stove top stuffing.
# 4 ounce shredded cheese
# []
# 1 cup peanut butter.
# []
# 3/4 cup graham cracker crumbs.
# []
# 1 cup melted butter.
# []
# 1 pound (3 1/2 cup) powdered sugar.
# [' (3 1/2 cup)']
#  (3 1/2 cup)
# 1 pound3 1/2 cup powdered sugar.
# 1 large package chocolate chips
# []
# 6 baking potatoes.
# []
# 1 pound of extra lean ground beef.
# []
# 2/3 cup butter or margarine.
# []
# 6 cup milk.
# []
# 3/4 teaspoon salt.
# []
# 1/2 teaspoon pepper.
# []
# 1 1/2 c (6 ounce) shredded cheddar cheese, divided.
# [' (6 ounce)']
#  (6 ounce)
# 1 1/2 c6 ounce shredded cheddar cheese, divided.
# 12 sliced bacon, cooked, crumbled and divided.
# []
# 4 green onion, chopped and divided.
# []
# 1 (8 ounce) carton sour cream (optional)
# ['1 (8 ounce) carton sour cream (optional)']
# 1 (8 ounce) carton sour cream (optional)
# 8 ounce
# 1 1/2 cup sugar.
# []
# 1/2 cup butter.
# []
# 1 egg.
# []
# 1 cup buttermilk.
# []
# 2 cup flour.
# []
# 1/2 teaspoon salt.
# []
# 1 teaspoon soda.
# []
# 1 cup buttermilk.
# []
# 2 cup rhubarb, finely cut.
# []
# 1 teaspoon vanilla
# []
# 1 can cream-style corn.
# []
# 1 can whole kernel corn.
# []
# 1/2 package (approximately 20) saltine crackers, crushed.
# [' (approximately 20)']
#  (approximately 20)
# 1/2 packageapproximately 20 saltine crackers, crushed.
# 1 egg, beaten.
# []
# 6 teaspoon butter, divided.
# []
# pepper to taste
# []
# 1 1/2 pound round steak (1-inch thick), cut into strips.
# [' (1-inch thick)']
#  (1-inch thick)
# 1 1/2 pound round steak1-inch thick, cut into strips.
# 1 can drained tomatoes, cut up (save liquid).
# [' (save liquid)']
#  (save liquid)
# 1 can drained tomatoes, cut upsave liquid.
# 1 3/4 cup water.
# []
# 1/2 cup onions.
# []
# 1 1/2 tablespoon worcestershire sauce.
# []
# 2 green peppers, diced.
# []
# 1/4 cup oil
# []
# 1 large container cool whip.
# []
# 1 large can crushed pineapple.
# []
# 1 can condensed milk.
# []
# 3 lemons.
# []
# 1 cup pecans.
# []
# 2 graham cracker crusts
# []
# 1 (17 ounce) can dark sweet pitted cherries.
# ['1 (17 ounce)']
# 1 (17 ounce)
# 17 ounce can dark sweet pitted cherries.
# 1/2 cup ginger ale.
# []
# 1 (6 ounce) package jell-o cherry flavor gelatin.
# ['1 (6 ounce)']
# 1 (6 ounce)
# 6 ounce package jell-o cherry flavor gelatin.
# 2 cup boiling water.
# []
# 1/8 teaspoon almond extract.
# []
# 1 cup miniature marshmallows
# []
# 1 box powdered sugar.
# []
# 8 ounce soft butter.
# []
# 1 (8 ounce) peanut butter.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce peanut butter.
# paraffin.
# []
# 12 ounce chocolate chips
# []
# chicken wings (as many as you need for dinner).
# [' (as many as you need for dinner)']
#  (as many as you need for dinner)
# chicken wingsas many as you need for dinner.
# flour.
# []
# barbecue sauce (your choice)
# [' (your choice)']
#  (your choice)
# barbecue sauceyour choice
# 8 ounce ortega taco sauce.
# []
# 8 ounce sour cream.
# []
# 8 ounce cream cheese.
# []
# 1 pound ground beef.
# []
# 1 package taco seasoning.
# []
# shredded lettuce.
# []
# 1 large diced tomato.
# []
# 1 medium diced onion.
# []
# 1 large diced green pepper.
# []
# shredded colby or cheddar cheese
# []
# 1 can pie filling (cherry or strawberry).
# [' (cherry or strawberry)']
#  (cherry or strawberry)
# 1 can pie fillingcherry or strawberry.
# 1 can crushed pineapple, drained.
# []
# 1 can sweetened condensed milk.
# []
# 1 (8 ounce) container thawed whipped topping.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce container thawed whipped topping.
# 2 tablespoon lemon juice
# []
# 1 baked pie shell.
# []
# 1 quart cleaned strawberries.
# []
# 1 1/2 cup water.
# []
# 4 tablespoon cornstarch.
# []
# 1 cup sugar.
# []
# 1/8 teaspoon salt.
# []
# 4 tablespoon strawberry jello
# []
# 1/2 package chocolate fudge cake mix without pudding or 1 jiffy mix.
# []
# 1/2 package white cake mix without pudding or 1 jiffy mix.
# []
# 1/4 cup wesson oil
# []
# 1 large head broccoli (about 1 1/2 pound).
# [' (about 1 1/2 pound)']
#  (about 1 1/2 pound)
# 1 large head broccoliabout 1 1/2 pound.
# 10 slices bacon, cooked and crumbled.
# []
# 5 green onions, sliced or 1/4 cup chopped red onion.
# []
# 1/2 cup raisins.
# []
# 1 cup mayonnaise.
# []
# 2 tablespoon vinegar.
# []
# 1/4 cup sugar
# []
# 1 pound frozen strawberries in juice.
# []
# 1 small can crushed pineapple.
# []
# 3 ripe bananas.
# []
# 1 cup chopped pecans.
# []
# 1 large package strawberry jell-o.
# []
# 1 1/2 cup boiling water.
# []
# 1 pint sour cream
# []
# 3/4 cup sugar.
# []
# 1/2 cup shortening.
# []
# 1 1/2 cup applesauce.
# []
# 3 level teaspoon soda.
# []
# 1 teaspoon each: cinnamon, cloves and nutmeg.
# []
# 2 cup sifted flour.
# []
# 1 cup raisins.
# []
# 1 cup nuts
# []
# 1 cup sugar.
# []
# 1/2 cup shortening.
# []
# 2 eggs (add one at a time).
# [' (add one at a time)']
#  (add one at a time)
# 2 eggsadd one at a time.
# 1 teaspoon salt.
# []
# 2 teaspoon soda.
# []
# 2 cup flour.
# []
# 1/4 cup nuts.
# []
# 2 over-ripe bananas (chopped)
# [' (chopped)']
#  (chopped)
# 2 over-ripe bananaschopped
# 1 package devil's food cake mix.
# []
# 1 package chocolate fudge pudding mix (instant).
# [' (instant)']
#  (instant)
# 1 package chocolate fudge pudding mixinstant.
# 8 ounce sour cream.
# []
# 3/4 cup water.
# []
# 1/2 cup wesson oil.
# []
# 4 eggs.
# []
# 6 ounce chopped frango mints
# []
# 2 cup 7-up or sprite.
# []
# 1 cup vegetable oil.
# []
# 1 cup kikkoman soy sauce.
# []
# garlic salt
# []
# 1/2 bushel tomatoes.
# []
# 1 cup oil.
# []
# 1/4 cup minced garlicup
# 6 cans tomato paste.
# []
# 3 peppers (2 sweet and 1 hot).
# [' (2 sweet and 1 hot)']
#  (2 sweet and 1 hot)
# 3 peppers2 sweet and 1 hot.
# 1 1/2 cup sugar.
# []
# 1/2 cup salt.
# []
# 1 tablespoon sweet basil.
# []
# 2 tablespoon oreganumber
# 1 teaspoon italian seasoning
# []
# 1 1/2 pound ground beef.
# []
# 1 cup tomato juice.
# []
# 3/4 cup oats (uncooked).
# [' (uncooked)']
#  (uncooked)
# 3/4 cup oatsuncooked.
# 1 egg, beaten.
# []
# 1/4 cup chopped onion.
# []
# 1/4 teaspoon pepper.
# []
# 1 1/2 teaspoon salt
# []
# 2 pound round steak.
# []
# 1/2 teaspoon ground black pepper.
# []
# 1 teaspoon ground white pepper.
# []
# 1/2 cup vegetable oil.
# []
# 2 bell peppers, chopped.
# []
# 1 cup beef stock or water.
# []
# 2 teaspoon salt.
# []
# 1 teaspoon ground red pepper.
# []
# all-purpose flour (dredging).
# [' (dredging)']
#  (dredging)
# all-purpose flourdredging.
# 3 medium onions, chopped.
# []
# 1 celery rib, chopped
# []
# 2 pound round steak 1/2 to 3/4-inch thick, sliced in strips 1/8-inch thick (or thinner) and 3 1/2 to 4-inches long (easily sliced if partially frozen).
# [' (or thinner) and 3 1/2 to 4-inches long (easily sliced if partially frozen)']
#  (or thinner) and 3 1/2 to 4-inches long (easily sliced if partially frozen)
# 2 pound round steak 1/2 to 3/4-inch thick, sliced in strips 1/8-inch thickor thinner.
# 2 tablespoon cooking oil.
# []
# 1 can (15 ounce) tomato sauce.
# [' (15 ounce)']
#  (15 ounce)
# 1 can15 ounce tomato sauce.
# 1/3 cup water.
# []
# 2 tablespoon brown sugar.
# []
# 1 tablespoon prepared mustard.
# []
# 1 tablespoon worcestershire sauce.
# []
# 1 medium sized onion, thinly sliced
# []
# 1 (14 ounce) can sweetened condensed milk.
# ['1 (14 ounce)']
# 1 (14 ounce)
# 14 ounce can sweetened condensed milk.
# 1 (12 ounce) package semi-sweet chocolate chips.
# ['1 (12 ounce)']
# 1 (12 ounce)
# 12 ounce package semi-sweet chocolate chips.
# 1 (1 ounce) square unsweetened chocolate (if desired).
# ['1 (1 ounce) square unsweetened chocolate (if desired)']
# 1 (1 ounce) square unsweetened chocolate (if desired)
# 1 ounce.
# 1 1/2 cup chopped nuts (if desired).
# [' (if desired)']
#  (if desired)
# 1 1/2 cup chopped nutsif desired.
# 1 teaspoon vanilla
# []
# 1 pound ground beef.
# []
# 1 package taco seasoning.
# []
# 1 san kidney beans.
# []
# 1 onion, chopped.
# []
# 1 c salsa.
# []
# 4 green peppers.
# []
# 1 medium tomato, chopped.
# []
# 1/2 c cheddar cheese, shredded.
# []
# 1/2 c sour cream
# []
# 1 cup milk.
# []
# 2 tablespoon sugar.
# []
# 1 package dry yeast.
# []
# 1 tablespoon salt.
# []
# 3 tablespoon crisco oil.
# []
# 2 cup plain flour
# []
# 2 large cans sliced peaches.
# []
# 2 large cans fruit cocktail.
# []
# 1 large can diced pineapple.
# []
# 1 quart fresh strawberries.
# []
# 2 red apples.
# []
# 2 yellow apples.
# []
# 4 large ripe bananas.
# []
# 1 pound white grapes.
# []
# 1 pound purple grapes
# []
# 1 package chicken cutlets.
# []
# 1/2 cup oil.
# []
# 1/3 cup red vinegar.
# []
# 2 tablespoon oreganumber
# 2 tablespoon garlic salt
# []
# 2 cans cherry pie mix.
# []
# 1 box deluxe white cake mix.
# []
# 1 stick butter.
# []
# 1 cup ground nuts
# []
# 3 eggs.
# []
# 1 teaspoon salt.
# []
# 1/4 teaspoon pepper.
# []
# 2 cup half and half.
# []
# 3 cup potatoes, shredded coarse.
# []
# 1 cup cheddar cheese, coarsely shredded.
# []
# 1/3 cup green onions
# []
# 1 box macaroni and cheese.
# []
# 1 can tuna, drained.
# []
# 1 small jar pimentos.
# []
# 1 medium onion, chopped
# []
# 2 cans or jars artichoke hearts.
# []
# 1 cup mayonnaise.
# []
# 1 cup parmesan cheese
# []
# 16 ounce sour cream.
# []
# 1 package dry vegetable soup mix.
# []
# 10 ounce package frozen chopped broccoli, thawed and drained.
# []
# 4 to 6 ounce cheddar cheese, grated
# []
# 1 pound very thin spaghetti.
# []
# 1/2 bottle mccormick salad supreme (seasoning).
# [' (seasoning)']
#  (seasoning)
# 1/2 bottle mccormick salad supremeseasoning.
# 1 bottle zesty italian dressing
# []
# 1 (16 ounce) can pear halves, undrained.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can pear halves, undrained.
# 1 (3 ounce) package lime gelatin.
# ['1 (3 ounce)']
# 1 (3 ounce)
# 3 ounce package lime gelatin.
# 1 (8 ounce) package cream cheese, softened.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce package cream cheese, softened.
# 1 (8 ounce) carton lemon yogurt
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce carton lemon yogurt
# 7 pound watermelon rind.
# []
# 7 cup sugar.
# []
# 2 cup apple vinegar.
# []
# 1/2 teaspoon oil of cloves.
# []
# 1/2 teaspoon oil of cinnamon
# []
# 3 pound chicken, boiled.
# []
# 4 medium potatoes, diced.
# []
# 2 medium onions, chopped.
# []
# 1 (16 ounce) can creamed corn.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can creamed corn.
# 1 (16 ounce) can english peas.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can english peas.
# 1 (16 ounce) can field peas.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can field peas.
# 1 (16 ounce) can butter beans.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can butter beans.
# 1 (16 ounce) can tomatoes.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can tomatoes.
# 1 (46 ounce) can tomato juice.
# ['1 (46 ounce)']
# 1 (46 ounce)
# 46 ounce can tomato juice.
# 1 small box macaroni.
# []
# 1 tablespoon black pepper.
# []
# 1 tablespoon salt.
# []
# 1 tablespoon sugar
# []
# 3 tablespoon softened butter or margarine.
# []
# 1/2 cup granulated sugar.
# []
# 1 egg.
# []
# 1 cup flour.
# []
# 1 1/4 teaspoon baking powder.
# []
# 1/4 teaspoon salt.
# []
# 1/3 cup milk.
# []
# 1/4 teaspoon vanilla.
# []
# 1/3 cup brown sugar, packed.
# []
# 1/2 teaspoon cinnamon.
# []
# 2 tablespoon butter or margarine
# []
# 5 cup flour.
# []
# 3 tablespoon sugar.
# []
# 4 teaspoon baking powder.
# []
# 1 1/2 package dry yeast.
# []
# 2 cup buttermilk.
# []
# 1 teaspoon soda.
# []
# 1 1/2 sticks margarine.
# []
# 1/2 cup warm water
# []
# 8 marshmallows.
# []
# 2 tablespoon margarine, melted.
# []
# 1/4 cup crushed peppermint candy.
# []
# 1 can crescent rolls
# []
# 1 box yellow cake mix.
# []
# 1/4 cup water.
# []
# 1/4 cup brown sugar.
# []
# 1/2 cup soft butter.
# []
# 2 eggs.
# []
# 1/2 cup chopped nuts
# []
# 1 cup flour.
# []
# 1 cup sugar.
# []
# 1/2 cup oleo, softened.
# []
# 4 eggs.
# []
# 1 can chocolate syrup
# []
# 3 cup self rising flour.
# []
# 1 - 12 ounce can beer.
# []
# 1 tablespoon sugar
# []
# 1/4 cup margarine.
# []
# 1/4 cup chopped onion (or as much as you want).
# [' (or as much as you want)']
#  (or as much as you want)
# 1/4 cup chopped onionor as much as you want.
# chopped celery to taste.
# []
# 1/4 cup flour.
# []
# 1/8 teaspoon curry powder.
# []
# 1 can sliced mushrooms (save juice).
# [' (save juice)']
#  (save juice)
# 1 can sliced mushroomssave juice.
# 1 can cream of celery soup.
# []
# 1 package chopped broccoli.
# []
# 1 cubed chicken.
# []
# shredded monterey jack cheese
# []
# 1 1/2 cup sifted flour.
# []
# 1/2 teaspoon baking powder.
# []
# 1/2 teaspoon salt.
# []
# 1/2 cup butter.
# []
# 2/3 cup sugar.
# []
# 3 egg yolks.
# []
# 1 teaspoon vanilla.
# []
# multi-colored candies
# []
# 1/2 pound ground beef.
# []
# 2 cup water.
# []
# 1 teaspoon sugar.
# []
# 1 package cup-a-soup onion soup mix (dry).
# [' (dry)']
#  (dry)
# 1 package cup-a-soup onion soup mixdry.
# 1 pound can stewed tomatoes.
# []
# 1 (8 ounce) can tomato sauce.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce can tomato sauce.
# 1 (10 ounce) package frozen mixed vegetables
# ['1 (10 ounce)']
# 1 (10 ounce)
# 10 ounce package frozen mixed vegetables
# 4 chicken breasts, cooked.
# []
# 1 can cream of chicken soup.
# []
# 1 can cream of mushroom soup.
# []
# 1 can green chili salsa sauce.
# []
# 1 can green chilies.
# []
# 1 cup milk.
# []
# 1 grated onion.
# []
# 1 package corn tortilla in pieces
# []
# 4 cup shredded cabbage.
# []
# 1/2 cup shredded carrots.
# []
# 1/4 cup finely chopped green pepper.
# []
# 2 tablespoon finely chopped onion.
# []
# 1/2 cup mayonnaise.
# []
# 1 tablespoon vinegar.
# []
# 2 teaspoon sugar.
# []
# 1 teaspoon celery seed.
# []
# 1/4 teaspoon salt
# []
# 2 pound flounder or pollack fillets.
# []
# 1 1/2 cup chopped tomatoes.
# []
# 1/2 cup chopped green pepper.
# []
# 1/3 cup lemon juice.
# []
# 1 tablespoon salad oil.
# []
# 2 teaspoon salt.
# []
# 2 teaspoon minced onion.
# []
# 1 teaspoon basil leaves.
# []
# 1/4 teaspoon coarsely ground black pepper.
# []
# 4 drops red pepper sauce.
# []
# green pepper rings
# []
# 1 can green beans, wash and drain.
# []
# 1 can yellow beans, wash and drain.
# []
# 1 can kidney beans, wash and drain.
# []
# 1 cup sugar.
# []
# 1/2 cup salad oil.
# []
# 2/3 cup vinegar.
# []
# 1/3 cup water
# []
# 1 (16 1/2 ounce) can whole kernel corn, drained.
# ['1 (16 1/2 ounce)']
# 1 (16 1/2 ounce)
# 16 1/2 ounce can whole kernel corn, drained.
# 1 (16 1/2 ounce) can cream-style corn.
# ['1 (16 1/2 ounce)']
# 1 (16 1/2 ounce)
# 16 1/2 ounce can cream-style corn.
# 1 (8 ounce) sour cream.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce sour cream.
# 1 (8 1/2 ounce) package jiffy corn bread mix.
# ['1 (8 1/2 ounce)']
# 1 (8 1/2 ounce)
# 8 1/2 ounce package jiffy corn bread mix.
# 1 stick margarine
# []
# 1 pound ground beef.
# []
# 1/3 cup chopped onion.
# []
# 1 can tomato soup.
# []
# 2 cup cooked wide noodles.
# []
# 1/2 teaspoon oreganumber
# 1/2 teaspoon salt.
# []
# 1/3 cup water.
# []
# 1 cup cheese
# []
# 1 small cabbage, shredded.
# []
# 1 teaspoon dry mustard.
# []
# 1 can corned beef, flaked.
# []
# 1 can cream of celery soup.
# []
# 1 medium chopped onion
# []
# 1 tablespoon worcestershire sauce.
# []
# 2 or 3 shakes old bay.
# []
# 1 teaspoon dry mustard.
# []
# 2 tablespoon mayonnaise.
# []
# 1 egg
# []
# 2 (8 ounce) package cream cheese, softened.
# ['2 (8 ounce)']
# 2 (8 ounce)
# 8 ounce package cream cheese, softened.
# 1/2 cup mayonnaise or salad dressing.
# []
# 8 ounce mild taco sauce.
# []
# 2 to 4 thinly sliced green onions.
# []
# 1/2 green pepper, chopped.
# []
# 1 tomato, chopped.
# []
# 1 cup mozzarella cheese.
# []
# 1 cup cheddar cheese.
# []
# 1/2 cup black olives (optional).
# [' (optional)']
#  (optional)
# 1/2 cup black olivesoptional.
# tortilla chips
# []
# 1/2 pound soft butter.
# []
# 1/2 cup peanut butter.
# []
# 1/2 pound graham cracker crumbs.
# []
# 2 cup coconut.
# []
# 1/2 cup nut meats (optional).
# [' (optional)']
#  (optional)
# 1/2 cup nut meatsoptional.
# dash of vanilla
# []
# 1 pound orange sliced candy, chopped.
# []
# 2 cans angel flake coconut.
# []
# 2 cup chopped pecans.
# []
# 2 cans condensed milk.
# []
# 1 teaspoon vanilla.
# []
# 1 teaspoon orange flavoring
# []
# 1 yellow cake mix.
# []
# 2 eggs.
# []
# 1 stick oleo, melted.
# []
# 1 cup chopped nuts.
# []
# 2 eggs.
# []
# 8 ounce softened cream cheese.
# []
# 1 pound powdered sugar
# []
# 1 large can chunk pineapple.
# []
# 4 to 5 bananas
# []
# 1 can cream of mushroom soup.
# []
# 1 can cream of chicken soup.
# []
# 1 can cream of celery soup.
# []
# 1 cut up chicken.
# []
# 1/2 cup melted butter or margarine.
# []
# 1 1/2 cup uncooked rice
# []
# 1 (8 ounce) package cream cheese.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce package cream cheese.
# 1 can sweetened condensed milk.
# []
# 1/2 cup crushed pineapple.
# []
# 1/3 cup chopped nuts.
# []
# 1/3 cup lemon juice
# []
# 1 (8 ounce) jell-o sugar-free vanilla or french vanilla pudding (put in dry).
# ['1 (8 ounce) jell-o sugar-free vanilla or french vanilla pudding (put in dry)']
# 1 (8 ounce) jell-o sugar-free vanilla or french vanilla pudding (put in dry)
# 8 ounce.
# 1 (8 ounce) philadelphia light cream cheese.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce philadelphia light cream cheese.
# 2 tablespoon butter.
# []
# 2 tablespoon peanut butter or more if you would like
# []
# 4 medium peaches, peeled and chopped.
# []
# 1 to 1 1/4 cup sugar.
# []
# 1 1/4 cup sour cream (use light).
# [' (use light)']
#  (use light)
# 1 1/4 cup sour creamuse light.
# 1/4 cup lemon juice.
# []
# 3/4 to 1 teaspoon vanilla
# []
# 16 ounce cool whip.
# []
# 2 package frozen strawberries *.
# []
# 2 (9-inch) deep pan pie crusts.
# ['2 (9-inch)']
# 2 (9-inch)
# 9-inch deep pan pie crusts.
# 1 3/4 cup sugar.
# []
# 12 ounce cream cheese
# []
# 1 stick margarine.
# []
# 1 1/2 cup graham cracker crumbs.
# []
# 1/4 cup granulated sugar
# []
# 2 cup sifted flour.
# []
# 1 1/2 teaspoon baking soda.
# []
# 1/4 teaspoon salt.
# []
# 1/2 cup shortening.
# []
# 1 1/2 cup sugar.
# []
# 2 eggs, separated.
# []
# 1/2 cup cocoa.
# []
# water.
# []
# 1 teaspoon vanilla.
# []
# 1 cup milk
# []
# 3 medium apples, chopped.
# []
# 2 cup raisins.
# []
# 1 cup brown sugar.
# []
# 1 cup granulated sugar.
# []
# 2 tablespoon shortening.
# []
# 2 cup cold water.
# []
# 3 cup flour.
# []
# 2 teaspoon soda.
# []
# 1 teaspoon cinnamon.
# []
# 1 teaspoon nutmeg.
# []
# 1 teaspoon cloves.
# []
# 1 teaspoon salt.
# []
# 1 cup nuts
# []
# 6 cup diced potatoes.
# []
# 1/2 cup chopped onion.
# []
# 3/4 cup melted butter.
# []
# 1 can cream of chicken soup.
# []
# 1 (8 ounce) sour cream.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce sour cream.
# 1 cup grated cheddar cheese.
# []
# 2 cup crushed cornflakes
# []
# vanilla wafers.
# []
# butter
# []
# 2 2/3 cup sugar.
# []
# 2/3 cup white corn syrup (karo).
# [' (karo)']
#  (karo)
# 2/3 cup white corn syrupkaro.
# 2/3 cup cold water.
# []
# 2 egg whites.
# []
# 1 teaspoon vanilla.
# []
# 1 cup chopped nuts
# []
# apples.
# []
# 1/2 cup sugar.
# []
# 1 teaspoon cinnamon.
# []
# 1/4 cup sugar.
# []
# 1 cup flour.
# []
# dash of salt.
# []
# 1/2 cup corn flake crumbs.
# []
# 1 stick oleo
# []
# 2 cup bisquick.
# []
# 1 pound sausage.
# []
# 8 ounce package cheddar cheese, grated
# []
# chicken parts.
# []
# 1 can cream of chicken soup.
# []
# 1 can consomme.
# []
# 2 cup rice.
# []
# salt to taste.
# []
# pepper to taste
# []
# 1/2 cup celery.
# []
# 2 chopped onions.
# []
# 2 tablespoon butter.
# []
# 1 pound ground beef.
# []
# 2 tablespoon vinegar.
# []
# 2 tablespoon lemon juice.
# []
# 2 tablespoon brown sugar.
# []
# 1 1/2 tablespoon mustard.
# []
# 1 teaspoon salt.
# []
# 1 1/2 teaspoon pepper.
# []
# 1 cup catsup.
# []
# 1 cup water
# []
# 2 (13 3/4 ounce) cans chicken broth.
# ['2 (13 3/4 ounce)']
# 2 (13 3/4 ounce)
# 13 3/4 ounce cans chicken broth.
# 1 tablespoon cornstarch.
# []
# 1 well beaten egg.
# []
# 2 tablespoon sliced (1/4-inch) green onion
# [' (1/4-inch)']
#  (1/4-inch)
# 2 tablespoon sliced1/4-inch green onion
# 1/2 gallon apple juice.
# []
# 1 teaspoon allspice.
# []
# 1 teaspoon whole cloves.
# []
# 1 cinnamon stick.
# []
# 1 cup brown sugar
# []
# 1 tablespoon sesame seed, toasted.
# []
# 2 teaspoon grated ginger.
# []
# 2 tablespoon honey.
# []
# 2 tablespoon reduced-sodium soy sauce.
# []
# 4 (4 ounce) skinned chicken breast halves.
# ['4 (4 ounce)']
# 4 (4 ounce)
# 4 ounce skinned chicken breast halves.
# vegetable cooking spray.
# []
# thin green onion strips
# []
# 1 vidalia onion, chopped.
# []
# 1 (16 ounce) package fresh mushrooms.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce package fresh mushrooms.
# 2 green peppers.
# []
# 1 clove garlicup
# olive oil.
# []
# 6 pieces bread (buttered with either butter or margarine).
# [' (buttered with either butter or margarine)']
#  (buttered with either butter or margarine)
# 6 pieces breadbuttered with either butter or margarine.
# 6 eggs.
# []
# milk (as much as you would like; to fluff eggs)
# [' (as much as you would like; to fluff eggs)']
#  (as much as you would like; to fluff eggs)
# milkas much as you would like; to fluff eggs
# 1 (12 ounce) bag raw cranberries (2 cup).
# ['1 (12 ounce) bag raw cranberries (2 cup)']
# 1 (12 ounce) bag raw cranberries (2 cup)
# 12 ounce.
# 1 cup sugar.
# []
# 1 medium apple, peeled, cored and cut into wedges.
# []
# 1 orange, peeled, seeded and broken in wedges.
# []
# 1 (3 ounce) package orange gelatin.
# ['1 (3 ounce)']
# 1 (3 ounce)
# 3 ounce package orange gelatin.
# 1/2 cup nuts (optional)
# [' (optional)']
#  (optional)
# 1/2 cup nutsoptional
# 1 cup raw rice.
# []
# 1 can beef consomme.
# []
# 1 can french onion soup.
# []
# 1 (4 ounce) can mushrooms.
# ['1 (4 ounce)']
# 1 (4 ounce)
# 4 ounce can mushrooms.
# 1/2 stick margarine, cut up
# []
# 2 (3 ounce) package softened cream cheese.
# ['2 (3 ounce)']
# 2 (3 ounce)
# 3 ounce package softened cream cheese.
# 2 tablespoon margarine.
# []
# 2 tablespoon sugar.
# []
# 1 (16 ounce) can whole berry cranberry sauce.
# ['1 (16 ounce)']
# 1 (16 ounce)
# 16 ounce can whole berry cranberry sauce.
# 3/4 cup crushed pineapple, drained.
# []
# 1/2 cup chopped walnuts.
# []
# 1 cup whipping cream
# []
# 2 pound velveeta cheese.
# []
# 1 (15 ounce) can italian tomatoes.
# ['1 (15 ounce)']
# 1 (15 ounce)
# 15 ounce can italian tomatoes.
# 2 small cans green chili peppers.
# []
# 1/2 medium onion, minced.
# []
# 3 cloves garlicup
# 1/2 teaspoon salt
# []
# 1 1/3 cup flour.
# []
# 1 1/4 teaspoon salt.
# []
# 1/2 teaspoon soda.
# []
# 2 tablespoon sugar.
# []
# 3/4 tablespoon baking powder.
# []
# 1 egg, beaten.
# []
# 2/3 cup milk (more if batter is too thick).
# [' (more if batter is too thick)']
#  (more if batter is too thick)
# 2/3 cup milkmore if batter is too thick.
# oil (for frying).
# [' (for frying)']
#  (for frying)
# oilfor frying.
# powdered sugar
# []
# 4 pound confectioners sugar.
# []
# 1 cup cocoa.
# []
# 1 cup chopped nuts.
# []
# 1 pound margarine (not whipped).
# [' (not whipped)']
#  (not whipped)
# 1 pound margarinenot whipped.
# 1 pound velveeta.
# []
# 1 tablespoon vanilla
# []
# 3 pound squash.
# []
# 3 onions.
# []
# 1 pint sour cream.
# []
# 3 carrots, grated.
# []
# 2 cans chicken or mushroom soup.
# []
# 1 package pepperidge farm stuffing mix.
# []
# 1 stick butter.
# []
# salt and pepper to taste
# []
# 2 package cream cheese.
# []
# 2 cup shredded cheddar cheese (8 ounce).
# [' (8 ounce)']
#  (8 ounce)
# 2 cup shredded cheddar cheese8 ounce.
# 1 tablespoon chopped pimento.
# []
# 1 tablespoon chopped green pepper.
# []
# 1 tablespoon chopped onion.
# []
# 1 teaspoon lemon juice.
# []
# 2 teaspoon worcestershire sauce.
# []
# dash of tabasco sauce.
# []
# dash of salt
# []
# 1 large package apricot jello (6 ounce).
# [' (6 ounce)']
#  (6 ounce)
# 1 large package apricot jello6 ounce.
# 2/3 cup sugar.
# []
# 1 (8 ounce) package cream cheese.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce package cream cheese.
# 2 jars junior baby food apricots.
# []
# 1 (number 2) can crushed pineapple (20 ounce).
# ['1 (number 2) can crushed pineapple (20 ounce)']
# 1 (number 2) can crushed pineapple (20 ounce)
# number 2.
# 1 tall can evaporated milk, chilled and whipped.
# []
# 2/3 cup water
# []
# 3 cup plain flour (cake flour may be substituted for plain flour).
# [' (cake flour may be substituted for plain flour)']
#  (cake flour may be substituted for plain flour)
# 3 cup plain flourcake flour may be substituted for plain flour.
# 3 cup sugar.
# []
# 1/2 teaspoon baking powder.
# []
# 3 dashes of salt.
# []
# 5 eggs.
# []
# 2 sticks margarine.
# []
# 1/2 cup butter flavor crisco.
# []
# 1 cup sweet milk.
# []
# 1 to 2 tablespoon flavoring (lemon, vanilla or almond or a combination of the 3)
# [' (lemon, vanilla or almond or a combination of the 3)']
#  (lemon, vanilla or almond or a combination of the 3)
# 1 to 2 tablespoon flavoringlemon, vanilla or almond or a combination of the 3
# 2 loaves frozen bread, softened.
# []
# 1/2 cup margarine.
# []
# 1 cup brown sugar.
# []
# 1 large box vanilla pudding (not instant).
# [' (not instant)']
#  (not instant)
# 1 large box vanilla puddingnot instant.
# 2 tablespoon milk.
# []
# cinnamon to taste
# []
# 1 (8 ounce) can crescent rolls.
# ['1 (8 ounce)']
# 1 (8 ounce)
# 8 ounce can crescent rolls.
# 1 1/2 cup grated medium or sharp cheese.
# []
# 1 hen, cooked and diced.
# []
# 1 can cream of chicken soup.
# []
# 1 1/2 cup milk
# []
# 1 can spanish rice.
# []
# 1 can corned beef.
# []
# 1 diced onion.
# []
# 1/2 cup grated cheddar cheese
# []
# 3 (1 pound) cans pork and beans.
# ['3 (1 pound)']
# 3 (1 pound)
# 1 pound cans pork and beans.
# 1/2 cup bell pepper, chopped.
# []
# 1/2 cup onions, chopped.
# []
# 3/4 cup catsup.
# []
# 1/3 cup brown sugar, packed hard.
# []
# 1 teaspoon salt.
# []
# 1/3 teaspoon black pepper.
# []
# 1 pound ground beef.
# []
# 1 tablespoon oil
# []
# 2 cup diced cooked chicken.
# []
# 2 tablespoon shortening.
# []
# 1/2 cup onion (large chunks).
# [' (large chunks)']
#  (large chunks)
# 1/2 cup onionlarge chunks.
# 2 cup carrot chunks.
# []
# 1 1/4 cup water.
# []
# 3 chicken bouillon cubes.
# []
# 1/4 cup packed brown sugar.
# []
# 2 tablespoon cornstarch.
# []
# 1/4 teaspoon ginger.
# []
# 1/4 cup catsup.
# []
# 2 tablespoon vinegar.
# []
# 1 tablespoon soy sauce.
# []
# 1 cup green pepper (large chunks).
# [' (large chunks)']
#  (large chunks)
# 1 cup green pepperlarge chunks.
# 8 ounce pineapple chunks
# []
# 8 to 10 juicy oranges, peeled and diced.
# []
# 1 cup moist coconut.
# []
# 1/2 cup pecans, chopped.
# []
# 1/2 cup cherries, halved.
# []
# 1/4 cup sugar.
# []
# 1 cup orange juice
# []
# 1 cup creamy peanut butter.
# []
# 1 cup sugar.
# []
# 1 egg
# []

# %% [markdown]
# ## ANALISI

# %% [markdown]
# ### Stop words removal
# Nella colonna 'step' troviamo una serie di passaggi da compiere per creare la ricetta. Questi passaggi sono scritti in linguaggio naturale e possono essere semplificati rimuovendo delle parole dette stop words.

# %%
# OPTINAL -> Risultati in swr_dataset"

stop_words = set(stopwords.words('english'))
swr_dataset = dataset.copy(deep=True)

tk = lambda x,st: ' '.join([w for w in x if w not in st])
for index in range(len(dataset)):
    swr_dataset.iloc[index]['step'] = [tk(word_tokenize(sent), stop_words) for sent in dataset.iloc[index]['step']]

# %% [markdown]
# ### Stemming e Lemming
# Questi due processi potrebbero portare valore all'analisi del dominio. Il codice per entrambi viene proposto qui.

# %%
# OPTINAL -> Risultati in lem_dataset"

lemmatizer = WordNetLemmatizer()
lem_dataset = swr_dataset.copy(deep=True)

for index in range(len(swr_dataset)):
    lem_dataset.iloc[index]['step'] = stem_sent = [' '.join([lemmatizer.lemmatize(w) for w in word_tokenize(sent)]) for sent in swr_dataset.iloc[index]['step']]

# %%
# OPTINAL -> Risultati in stm_dataset"

stemmer = PorterStemmer()
stm_dataset = lem_dataset.copy(deep=True)

for index in range(len(lem_dataset)):
    stm_dataset.iloc[index]['step'] = [' '.join([stemmer.stem(w) for w in word_tokenize(sent)]) for sent in lem_dataset.iloc[index]['step']]

# %%
print("Frasi originali\n")
print(dataset.iloc[10]['step'])
print("\nStop word removal\n")
print(swr_dataset.iloc[10]['step'])
print("\nStop word e lemming\n")
print(lem_dataset.iloc[10]['step'])
print("\nStop word lemming e stemming\n")
print(stm_dataset.iloc[10]['step'])
# Out:
# Frasi originali
#
# ['Mix sugar, butter and peanut butter.', 'Roll into balls and place on cookie sheet.', 'Set in freezer for at least 30 minutes.', 'Melt chocolate chips and paraffin in double boiler.', 'Using a toothpick, dip balls 3/4 of way into chocolate chip and paraffin mixture to make them look like buckeyes.']
#
# Stop word removal
#
# ['Mix sugar , butter peanut butter .', 'Roll balls place cookie sheet .', 'Set freezer least 30 minutes .', 'Melt chocolate chips paraffin double boiler .', 'Using toothpick , dip balls 3/4 way chocolate chip paraffin mixture make look like buckeyes .']
#
# Stop word e lemming
#
# ['Mix sugar , butter peanut butter .', 'Roll ball place cookie sheet .', 'Set freezer least 30 minute .', 'Melt chocolate chip paraffin double boiler .', 'Using toothpick , dip ball 3/4 way chocolate chip paraffin mixture make look like buckeye .']
#
# Stop word lemming e stemming
#
# ['mix sugar , butter peanut butter .', 'roll ball place cooki sheet .', 'set freezer least 30 minut .', 'melt chocol chip paraffin doubl boiler .', 'use toothpick , dip ball 3/4 way chocol chip paraffin mixtur make look like buckey .']

# %% [markdown]
# ### Entity Extraction and relation extraction and POS-Tagging
# Questa operazione ci permette di riconoscere le parti del testo. !!!Attualmente vengono solo stampate, ma in seguito le utilizzeremo a modo!!!

# %%
spacy_dataset = dataset.copy(deep=True)
       
for index in range(len(dataset)):
    spacy_dataset.iloc[index]['ingredients'] = [NLP(element) for element in dataset.iloc[index]['ingredients']]
    spacy_dataset.iloc[index]['step'] = [NLP(element) for element in dataset.iloc[index]['step']]

# %%
def __pprintsp__(dataset, index, column, value, extend=False):
    displacy.render(dataset.iloc[index][column][value], style='dep')
    print(dataset.iloc[index][column][value])
    displacy.render(dataset.iloc[index][column][value], style='ent')
    if extend:
        for token in dataset.iloc[index][column][value]:
            print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)

def pprint_spacyd_all(dataset, index, column, extend=False):
    for v in range(len(dataset.iloc[index][column])):
        __pprintsp__(dataset, index, column, v, extend)
            
def pprint_spacyd(dataset, index, column, value, extend=False):
    __pprintsp__(dataset, index, column, v, extend)

# %%
pprint_spacyd_all(spacy_dataset, 2, 'ingredients')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="72c0937b1c714b3fb4bfb23d16c97728-0" class="displacy" width="750" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">large</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">whole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">chicken.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72c0937b1c714b3fb4bfb23d16c97728-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72c0937b1c714b3fb4bfb23d16c97728-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72c0937b1c714b3fb4bfb23d16c97728-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72c0937b1c714b3fb4bfb23d16c97728-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72c0937b1c714b3fb4bfb23d16c97728-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72c0937b1c714b3fb4bfb23d16c97728-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# 1 large whole chicken.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  large whole chicken.</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a2741cb4d7ad413389994b1c85545b3f-0" class="displacy" width="1275" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">2 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">1/2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">ounce)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">cans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">chicken</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">gravy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 750.0,2.0 750.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-3" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,354.0 L578.0,342.0 562.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2741cb4d7ad413389994b1c85545b3f-0-5" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2741cb4d7ad413389994b1c85545b3f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,354.0 L1098.0,342.0 1082.0,342.0" fill="currentColor"/>
# </g>
# </svg></span>
# 2 (10 1/2 ounce) cans chicken gravy.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 1/2 ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# )
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cans chicken gravy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0f2716e89b59450bb9a7bda87f7c8f12-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">1 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">1/2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">ounce)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">cream</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">mushroom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">soup.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 925.0,2.0 925.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">meta</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-3" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,354.0 L578.0,342.0 562.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-7" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f2716e89b59450bb9a7bda87f7c8f12-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1440.0,354.0 L1448.0,342.0 1432.0,342.0" fill="currentColor"/>
# </g>
# </svg></span>
# 1 (10 1/2 ounce) can cream of mushroom soup.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 1/2 ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# ) can cream of mushroom soup.</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4b6fdeebcc4846b7865bc4fb822a5c3f-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">1 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">ounce)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">box</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">stove</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">stuffing.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">meta</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-2" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,266.5 L403.0,254.5 387.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b6fdeebcc4846b7865bc4fb822a5c3f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# 1 (6 ounce) box stove top stuffing.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# ) box stove top stuffing.</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="509c45598ada4c07942c08e0a0c3b19f-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">ounce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">shredded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">cheese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-509c45598ada4c07942c08e0a0c3b19f-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-509c45598ada4c07942c08e0a0c3b19f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-509c45598ada4c07942c08e0a0c3b19f-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-509c45598ada4c07942c08e0a0c3b19f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,91.5 L237,79.5 253,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-509c45598ada4c07942c08e0a0c3b19f-0-2" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-509c45598ada4c07942c08e0a0c3b19f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,91.5 L412,79.5 428,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# 4 ounce shredded cheese
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  shredded cheese</div></span>
